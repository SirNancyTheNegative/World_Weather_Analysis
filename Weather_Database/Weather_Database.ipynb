# %%
# Import the dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
from config import weather_api_key
import requests

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
coords = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coord in coords:
    city = citipy.nearest_city(coord[0],coord[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 767

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_name = city_weather["name"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | kapaa
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | tautira
# Processing Record 6 of Set 1 | sarkand
# Processing Record 7 of Set 1 | sodertalje
# City not found. Skipping...
# Processing Record 8 of Set 1 | pustoshka
# Processing Record 9 of Set 1 | clearlake
# Processing Record 10 of Set 1 | casablanca
# Processing Record 11 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 1 | hami
# Processing Record 14 of Set 1 | vila
# Processing Record 15 of Set 1 | new norfolk
# Processing Record 16 of Set 1 | vostok
# Processing Record 17 of Set 1 | hualmay
# Processing Record 18 of Set 1 | mandera
# Processing Record 19 of Set 1 | santiago
# Processing Record 20 of Set 1 | atuona
# Processing Record 21 of Set 1 | kysyl-syr
# Processing Record 22 of Set 1 | carnarvon
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | lokosovo
# Processing Record 25 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 1 | santa cruz
# Processing Record 28 of Set 1 | hilo
# Processing Record 29 of Set 1 | henties bay
# Processing Record 30 of Set 1 | nikolskoye
# Processing Record 31 of Set 1 | albany
# Processing Record 32 of Set 1 | vaini
# Processing Record 33 of Set 1 | dikson
# Processing Record 34 of Set 1 | saldanha
# Processing Record 35 of Set 1 | qaanaaq
# Processing Record 36 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 1 | tasiilaq
# Processing Record 38 of Set 1 | portland
# Processing Record 39 of Set 1 | moree
# Processing Record 40 of Set 1 | faya
# Processing Record 41 of Set 1 | bredasdorp
# Processing Record 42 of Set 1 | belyy yar
# Processing Record 43 of Set 1 | sept-iles
# Processing Record 44 of Set 1 | deep river
# Processing Record 45 of Set 1 | namibe
# Processing Record 46 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 1 | mar del plata
# Processing Record 48 of Set 1 | college
# Processing Record 49 of Set 1 | gayeri
# Processing Record 50 of Set 1 | anapskaya
# Processing Record 1 of Set 2 | hermanus
# Processing Record 2 of Set 2 | hobart
# Processing Record 3 of Set 2 | punta arenas
# Processing Record 4 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 2 | barrow
# Processing Record 6 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 2 | san pedro
# Processing Record 8 of Set 2 | east london
# Processing Record 9 of Set 2 | dinsor
# City not found. Skipping...
# Processing Record 10 of Set 2 | tocopilla
# Processing Record 11 of Set 2 | birao
# Processing Record 12 of Set 2 | kodiak
# Processing Record 13 of Set 2 | ostersund
# Processing Record 14 of Set 2 | kruisfontein
# Processing Record 15 of Set 2 | jamestown
# Processing Record 16 of Set 2 | grindavik
# Processing Record 17 of Set 2 | avarua
# Processing Record 18 of Set 2 | severo-kurilsk
# Processing Record 19 of Set 2 | honningsvag
# Processing Record 20 of Set 2 | necochea
# Processing Record 21 of Set 2 | salalah
# Processing Record 22 of Set 2 | jaipur hat
# City not found. Skipping...
# Processing Record 23 of Set 2 | meulaboh
# Processing Record 24 of Set 2 | tebingtinggi
# Processing Record 25 of Set 2 | shitanjing
# Processing Record 26 of Set 2 | ambovombe
# Processing Record 27 of Set 2 | provideniya
# Processing Record 28 of Set 2 | puerto ayora
# Processing Record 29 of Set 2 | shar
# Processing Record 30 of Set 2 | bengkulu
# Processing Record 31 of Set 2 | cherskiy
# Processing Record 32 of Set 2 | leh
# Processing Record 33 of Set 2 | magadan
# Processing Record 34 of Set 2 | mahebourg
# Processing Record 35 of Set 2 | cape town
# Processing Record 36 of Set 2 | cidreira
# Processing Record 37 of Set 2 | manyana
# Processing Record 38 of Set 2 | oranjemund
# Processing Record 39 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 2 | bluff
# Processing Record 41 of Set 2 | bac lieu
# Processing Record 42 of Set 2 | arraial do cabo
# Processing Record 43 of Set 2 | dryden
# Processing Record 44 of Set 2 | gamba
# Processing Record 45 of Set 2 | deputatskiy
# Processing Record 46 of Set 2 | okha
# Processing Record 47 of Set 2 | koslan
# Processing Record 48 of Set 2 | iisalmi
# Processing Record 49 of Set 2 | avera
# Processing Record 50 of Set 2 | belmonte
# Processing Record 1 of Set 3 | port alfred
# Processing Record 2 of Set 3 | comodoro rivadavia
# Processing Record 3 of Set 3 | maragogi
# Processing Record 4 of Set 3 | madimba
# Processing Record 5 of Set 3 | saint george
# Processing Record 6 of Set 3 | kudahuvadhoo
# Processing Record 7 of Set 3 | port hardy
# Processing Record 8 of Set 3 | ossora
# Processing Record 9 of Set 3 | utica
# Processing Record 10 of Set 3 | bilma
# Processing Record 11 of Set 3 | ponta do sol
# Processing Record 12 of Set 3 | clyde river
# Processing Record 13 of Set 3 | mareeba
# Processing Record 14 of Set 3 | dunedin
# Processing Record 15 of Set 3 | westport
# Processing Record 16 of Set 3 | gillette
# Processing Record 17 of Set 3 | tuktoyaktuk
# Processing Record 18 of Set 3 | totness
# Processing Record 19 of Set 3 | japura
# Processing Record 20 of Set 3 | payo
# Processing Record 21 of Set 3 | yellowknife
# Processing Record 22 of Set 3 | lavrentiya
# Processing Record 23 of Set 3 | chokurdakh
# Processing Record 24 of Set 3 | khatanga
# Processing Record 25 of Set 3 | saint-augustin
# Processing Record 26 of Set 3 | calvia
# Processing Record 27 of Set 3 | mayumba
# Processing Record 28 of Set 3 | yeppoon
# Processing Record 29 of Set 3 | tual
# Processing Record 30 of Set 3 | hamilton
# Processing Record 31 of Set 3 | cairo montenotte
# Processing Record 32 of Set 3 | bela
# Processing Record 33 of Set 3 | igarka
# Processing Record 34 of Set 3 | businga
# Processing Record 35 of Set 3 | hithadhoo
# Processing Record 36 of Set 3 | lagoa
# Processing Record 37 of Set 3 | butaritari
# Processing Record 38 of Set 3 | ayr
# Processing Record 39 of Set 3 | cabinda
# Processing Record 40 of Set 3 | egvekinot
# Processing Record 41 of Set 3 | rosetta
# Processing Record 42 of Set 3 | north bend
# Processing Record 43 of Set 3 | porosozero
# Processing Record 44 of Set 3 | synya
# Processing Record 45 of Set 3 | penzance
# Processing Record 46 of Set 3 | hofn
# Processing Record 47 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 3 | beira
# Processing Record 49 of Set 3 | acapulco
# Processing Record 50 of Set 3 | zuya
# Processing Record 1 of Set 4 | natal
# Processing Record 2 of Set 4 | juneau
# Processing Record 3 of Set 4 | ereymentau
# Processing Record 4 of Set 4 | brewster
# Processing Record 5 of Set 4 | bethel
# Processing Record 6 of Set 4 | leshukonskoye
# Processing Record 7 of Set 4 | kremze
# Processing Record 8 of Set 4 | falealupo
# City not found. Skipping...
# Processing Record 9 of Set 4 | broome
# Processing Record 10 of Set 4 | ahuimanu
# Processing Record 11 of Set 4 | ostrovnoy
# Processing Record 12 of Set 4 | kahului
# Processing Record 13 of Set 4 | longyearbyen
# Processing Record 14 of Set 4 | lima
# Processing Record 15 of Set 4 | kavieng
# Processing Record 16 of Set 4 | bacungan
# Processing Record 17 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 4 | komsomolskiy
# Processing Record 19 of Set 4 | cayenne
# Processing Record 20 of Set 4 | oudtshoorn
# Processing Record 21 of Set 4 | houma
# Processing Record 22 of Set 4 | omboue
# Processing Record 23 of Set 4 | ambunti
# Processing Record 24 of Set 4 | souillac
# Processing Record 25 of Set 4 | griffith
# Processing Record 26 of Set 4 | hasaki
# Processing Record 27 of Set 4 | katsuura
# Processing Record 28 of Set 4 | beidao
# Processing Record 29 of Set 4 | constitucion
# Processing Record 30 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 4 | kirakira
# Processing Record 32 of Set 4 | tilichiki
# Processing Record 33 of Set 4 | wilson
# Processing Record 34 of Set 4 | rio gallegos
# Processing Record 35 of Set 4 | luderitz
# Processing Record 36 of Set 4 | luanda
# Processing Record 37 of Set 4 | saint-pierre
# Processing Record 38 of Set 4 | harnosand
# Processing Record 39 of Set 4 | mizan teferi
# Processing Record 40 of Set 4 | ataco
# Processing Record 41 of Set 4 | sao filipe
# Processing Record 42 of Set 4 | georgetown
# Processing Record 43 of Set 4 | shingu
# Processing Record 44 of Set 4 | zhezkazgan
# Processing Record 45 of Set 4 | vestmanna
# Processing Record 46 of Set 4 | vardo
# Processing Record 47 of Set 4 | guadalupe y calvo
# Processing Record 48 of Set 4 | kaitangata
# Processing Record 49 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 4 | andros town
# Processing Record 1 of Set 5 | buraydah
# Processing Record 2 of Set 5 | nome
# Processing Record 3 of Set 5 | gizo
# Processing Record 4 of Set 5 | lebu
# Processing Record 5 of Set 5 | chuy
# Processing Record 6 of Set 5 | atherton
# Processing Record 7 of Set 5 | swan river
# Processing Record 8 of Set 5 | goundam
# Processing Record 9 of Set 5 | lucea
# Processing Record 10 of Set 5 | massakory
# Processing Record 11 of Set 5 | torbay
# Processing Record 12 of Set 5 | tirukkattuppalli
# City not found. Skipping...
# Processing Record 13 of Set 5 | atchison
# Processing Record 14 of Set 5 | qaqortoq
# Processing Record 15 of Set 5 | boljarovo
# City not found. Skipping...
# Processing Record 16 of Set 5 | ko samui
# Processing Record 17 of Set 5 | alekseyevka
# Processing Record 18 of Set 5 | jinxiang
# Processing Record 19 of Set 5 | vila franca do campo
# Processing Record 20 of Set 5 | labuhan
# Processing Record 21 of Set 5 | venado
# Processing Record 22 of Set 5 | bambous virieux
# Processing Record 23 of Set 5 | ilebo
# Processing Record 24 of Set 5 | kovur
# Processing Record 25 of Set 5 | ksenyevka
# City not found. Skipping...
# Processing Record 26 of Set 5 | aguimes
# Processing Record 27 of Set 5 | pimentel
# Processing Record 28 of Set 5 | mount gambier
# Processing Record 29 of Set 5 | rongcheng
# Processing Record 30 of Set 5 | nantucket
# Processing Record 31 of Set 5 | neiafu
# Processing Record 32 of Set 5 | yar-sale
# Processing Record 33 of Set 5 | flinders
# Processing Record 34 of Set 5 | port lincoln
# Processing Record 35 of Set 5 | maracacume
# Processing Record 36 of Set 5 | yulara
# Processing Record 37 of Set 5 | castro
# Processing Record 38 of Set 5 | tefe
# Processing Record 39 of Set 5 | great yarmouth
# Processing Record 40 of Set 5 | voh
# Processing Record 41 of Set 5 | bathsheba
# Processing Record 42 of Set 5 | nishihara
# Processing Record 43 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 44 of Set 5 | pochutla
# Processing Record 45 of Set 5 | lesosibirsk
# Processing Record 46 of Set 5 | norman wells
# Processing Record 47 of Set 5 | tonantins
# Processing Record 48 of Set 5 | djambala
# Processing Record 49 of Set 5 | marawi
# Processing Record 50 of Set 5 | ust-ordynskiy
# Processing Record 1 of Set 6 | eenhana
# Processing Record 2 of Set 6 | karratha
# Processing Record 3 of Set 6 | aksarka
# Processing Record 4 of Set 6 | mayo
# Processing Record 5 of Set 6 | lorengau
# Processing Record 6 of Set 6 | solnechnyy
# Processing Record 7 of Set 6 | tiksi
# Processing Record 8 of Set 6 | itarema
# Processing Record 9 of Set 6 | sao joao da barra
# Processing Record 10 of Set 6 | annau
# Processing Record 11 of Set 6 | burns lake
# Processing Record 12 of Set 6 | quatre cocos
# Processing Record 13 of Set 6 | walvis bay
# Processing Record 14 of Set 6 | waingapu
# Processing Record 15 of Set 6 | saskylakh
# Processing Record 16 of Set 6 | ocos
# Processing Record 17 of Set 6 | tiznit
# Processing Record 18 of Set 6 | moses lake
# Processing Record 19 of Set 6 | alibag
# Processing Record 20 of Set 6 | saint-philippe
# Processing Record 21 of Set 6 | harper
# Processing Record 22 of Set 6 | soloneshnoye
# Processing Record 23 of Set 6 | nerchinskiy zavod
# Processing Record 24 of Set 6 | fortuna
# Processing Record 25 of Set 6 | geraldton
# Processing Record 26 of Set 6 | kataysk
# Processing Record 27 of Set 6 | mount isa
# Processing Record 28 of Set 6 | merauke
# Processing Record 29 of Set 6 | navahrudak
# Processing Record 30 of Set 6 | port elizabeth
# Processing Record 31 of Set 6 | huntington
# Processing Record 32 of Set 6 | cooma
# Processing Record 33 of Set 6 | zaraza
# Processing Record 34 of Set 6 | ushibuka
# Processing Record 35 of Set 6 | palmerston
# Processing Record 36 of Set 6 | dolores
# Processing Record 37 of Set 6 | kaeo
# Processing Record 38 of Set 6 | realeza
# Processing Record 39 of Set 6 | bandarbeyla
# Processing Record 40 of Set 6 | sokolo
# Processing Record 41 of Set 6 | shahr-e babak
# Processing Record 42 of Set 6 | semey
# Processing Record 43 of Set 6 | te anau
# Processing Record 44 of Set 6 | canton
# Processing Record 45 of Set 6 | buala
# Processing Record 46 of Set 6 | mercedes
# Processing Record 47 of Set 6 | cherlak
# Processing Record 48 of Set 6 | dubenskiy
# City not found. Skipping...
# Processing Record 49 of Set 6 | saint-georges
# Processing Record 50 of Set 6 | ewa beach
# Processing Record 1 of Set 7 | paliyad
# Processing Record 2 of Set 7 | marsh harbour
# Processing Record 3 of Set 7 | andarab
# City not found. Skipping...
# Processing Record 4 of Set 7 | narsaq
# Processing Record 5 of Set 7 | pascagoula
# Processing Record 6 of Set 7 | council bluffs
# Processing Record 7 of Set 7 | eureka
# Processing Record 8 of Set 7 | mahibadhoo
# Processing Record 9 of Set 7 | arlit
# Processing Record 10 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 7 | envira
# Processing Record 12 of Set 7 | belaya gora
# Processing Record 13 of Set 7 | havre-saint-pierre
# Processing Record 14 of Set 7 | boulder city
# Processing Record 15 of Set 7 | vyazma
# Processing Record 16 of Set 7 | abu kamal
# Processing Record 17 of Set 7 | tabukiniberu
# City not found. Skipping...
# Processing Record 18 of Set 7 | coquimbo
# Processing Record 19 of Set 7 | benjamin constant
# Processing Record 20 of Set 7 | tawang
# Processing Record 21 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 22 of Set 7 | borogontsy
# Processing Record 23 of Set 7 | tsiroanomandidy
# Processing Record 24 of Set 7 | gasa
# Processing Record 25 of Set 7 | along
# Processing Record 26 of Set 7 | aksu
# Processing Record 27 of Set 7 | lichuan
# Processing Record 28 of Set 7 | kroya
# Processing Record 29 of Set 7 | coari
# Processing Record 30 of Set 7 | miraflores
# Processing Record 31 of Set 7 | cockburn town
# Processing Record 32 of Set 7 | yumen
# Processing Record 33 of Set 7 | klaksvik
# Processing Record 34 of Set 7 | umm lajj
# Processing Record 35 of Set 7 | hobyo
# Processing Record 36 of Set 7 | spring valley
# Processing Record 37 of Set 7 | kyra
# Processing Record 38 of Set 7 | zabaykalsk
# Processing Record 39 of Set 7 | guerrero negro
# Processing Record 40 of Set 7 | montepuez
# Processing Record 41 of Set 7 | laguna
# Processing Record 42 of Set 7 | sorland
# Processing Record 43 of Set 7 | nemuro
# Processing Record 44 of Set 7 | kalamazoo
# Processing Record 45 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 7 | bom jesus
# Processing Record 47 of Set 7 | hilton head island
# Processing Record 48 of Set 7 | richards bay
# Processing Record 49 of Set 7 | ribeira grande
# Processing Record 50 of Set 7 | thompson
# Processing Record 1 of Set 8 | cairns
# Processing Record 2 of Set 8 | dudinka
# Processing Record 3 of Set 8 | blackwater
# Processing Record 4 of Set 8 | colares
# Processing Record 5 of Set 8 | gallipoli
# Processing Record 6 of Set 8 | burriana
# Processing Record 7 of Set 8 | sao jose da coroa grande
# Processing Record 8 of Set 8 | dunda
# Processing Record 9 of Set 8 | gondar
# Processing Record 10 of Set 8 | voyvozh
# Processing Record 11 of Set 8 | jiblah
# Processing Record 12 of Set 8 | faanui
# Processing Record 13 of Set 8 | sarangani
# Processing Record 14 of Set 8 | coihaique
# Processing Record 15 of Set 8 | lagos
# Processing Record 16 of Set 8 | tema
# Processing Record 17 of Set 8 | itacare
# Processing Record 18 of Set 8 | dingle
# Processing Record 19 of Set 8 | brigantine
# Processing Record 20 of Set 8 | ponta delgada
# Processing Record 21 of Set 8 | lata
# Processing Record 22 of Set 8 | ponferrada
# Processing Record 23 of Set 8 | sarai naurang
# Processing Record 24 of Set 8 | turinskaya sloboda
# Processing Record 25 of Set 8 | cabo san lucas
# Processing Record 26 of Set 8 | mana
# Processing Record 27 of Set 8 | bilibino
# Processing Record 28 of Set 8 | kasongo-lunda
# Processing Record 29 of Set 8 | chicama
# Processing Record 30 of Set 8 | tabora
# Processing Record 31 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 8 | ambanja
# Processing Record 33 of Set 8 | victoria
# Processing Record 34 of Set 8 | faranah
# Processing Record 35 of Set 8 | rawson
# Processing Record 36 of Set 8 | muros
# Processing Record 37 of Set 8 | sibolga
# Processing Record 38 of Set 8 | stoyba
# City not found. Skipping...
# Processing Record 39 of Set 8 | vung tau
# Processing Record 40 of Set 8 | vanimo
# Processing Record 41 of Set 8 | ilulissat
# Processing Record 42 of Set 8 | arkadak
# Processing Record 43 of Set 8 | campo verde
# Processing Record 44 of Set 8 | concordia
# Processing Record 45 of Set 8 | zhangye
# Processing Record 46 of Set 8 | yarmouth
# Processing Record 47 of Set 8 | upernavik
# Processing Record 48 of Set 8 | pangnirtung
# Processing Record 49 of Set 8 | esperance
# Processing Record 50 of Set 8 | takoradi
# Processing Record 1 of Set 9 | sheridan
# Processing Record 2 of Set 9 | huadian
# Processing Record 3 of Set 9 | ibotirama
# Processing Record 4 of Set 9 | ust-shonosha
# Processing Record 5 of Set 9 | silifke
# Processing Record 6 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 7 of Set 9 | nizhniy kuranakh
# Processing Record 8 of Set 9 | tuatapere
# Processing Record 9 of Set 9 | labytnangi
# Processing Record 10 of Set 9 | leningradskiy
# Processing Record 11 of Set 9 | viedma
# Processing Record 12 of Set 9 | andenes
# Processing Record 13 of Set 9 | auki
# Processing Record 14 of Set 9 | san cristobal
# Processing Record 15 of Set 9 | san angelo
# Processing Record 16 of Set 9 | xining
# Processing Record 17 of Set 9 | airai
# Processing Record 18 of Set 9 | gdov
# Processing Record 19 of Set 9 | prieska
# Processing Record 20 of Set 9 | toamua
# City not found. Skipping...
# Processing Record 21 of Set 9 | heyang
# Processing Record 22 of Set 9 | nouadhibou
# Processing Record 23 of Set 9 | antigonish
# Processing Record 24 of Set 9 | impfondo
# Processing Record 25 of Set 9 | loandjili
# Processing Record 26 of Set 9 | dhidhdhoo
# Processing Record 27 of Set 9 | naze
# Processing Record 28 of Set 9 | porto novo
# Processing Record 29 of Set 9 | cockburn harbour
# City not found. Skipping...
# Processing Record 30 of Set 9 | samarai
# Processing Record 31 of Set 9 | pontes e lacerda
# Processing Record 32 of Set 9 | smiths falls
# Processing Record 33 of Set 9 | chapleau
# Processing Record 34 of Set 9 | pevek
# Processing Record 35 of Set 9 | rapid valley
# Processing Record 36 of Set 9 | ballina
# Processing Record 37 of Set 9 | skjervoy
# Processing Record 38 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 39 of Set 9 | talmenka
# Processing Record 40 of Set 9 | kailua
# Processing Record 41 of Set 9 | abashiri
# Processing Record 42 of Set 9 | bingol
# Processing Record 43 of Set 9 | alofi
# Processing Record 44 of Set 9 | dzaoudzi
# Processing Record 45 of Set 9 | toamasina
# Processing Record 46 of Set 9 | hit
# Processing Record 47 of Set 9 | misratah
# Processing Record 48 of Set 9 | louga
# Processing Record 49 of Set 9 | rudbar
# Processing Record 50 of Set 9 | postojna
# Processing Record 1 of Set 10 | felipe carrillo puerto
# Processing Record 2 of Set 10 | ancud
# Processing Record 3 of Set 10 | sola
# Processing Record 4 of Set 10 | vredendal
# Processing Record 5 of Set 10 | puhja
# Processing Record 6 of Set 10 | butler
# Processing Record 7 of Set 10 | tome
# Processing Record 8 of Set 10 | gayny
# Processing Record 9 of Set 10 | zagare
# Processing Record 10 of Set 10 | baykalsk
# Processing Record 11 of Set 10 | paragominas
# Processing Record 12 of Set 10 | onverwacht
# Processing Record 13 of Set 10 | astana
# Processing Record 14 of Set 10 | dongsheng
# Processing Record 15 of Set 10 | tanza
# Processing Record 16 of Set 10 | ixtapa
# Processing Record 17 of Set 10 | beringovskiy
# Processing Record 18 of Set 10 | ingham
# Processing Record 19 of Set 10 | colac
# Processing Record 20 of Set 10 | high level
# Processing Record 21 of Set 10 | kloulklubed
# Processing Record 22 of Set 10 | wawa
# Processing Record 23 of Set 10 | sainte-marie
# Processing Record 24 of Set 10 | grand gaube
# Processing Record 25 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 26 of Set 10 | poso
# Processing Record 27 of Set 10 | verkhniye tatyshly
# Processing Record 28 of Set 10 | kizukuri
# Processing Record 29 of Set 10 | high prairie
# Processing Record 30 of Set 10 | nusaybin
# Processing Record 31 of Set 10 | zaysan
# Processing Record 32 of Set 10 | lompoc
# Processing Record 33 of Set 10 | sitka
# Processing Record 34 of Set 10 | kiama
# Processing Record 35 of Set 10 | kamenka
# Processing Record 36 of Set 10 | mingshui
# Processing Record 37 of Set 10 | maxixe
# Processing Record 38 of Set 10 | sur
# Processing Record 39 of Set 10 | karaton
# Processing Record 40 of Set 10 | bonthe
# Processing Record 41 of Set 10 | morondava
# Processing Record 42 of Set 10 | safranbolu
# Processing Record 43 of Set 10 | vysokogornyy
# Processing Record 44 of Set 10 | ghedi
# Processing Record 45 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 10 | sanchor
# Processing Record 47 of Set 10 | lashio
# Processing Record 48 of Set 10 | cordoba
# Processing Record 49 of Set 10 | revda
# Processing Record 50 of Set 10 | san andres
# Processing Record 1 of Set 11 | pisco
# Processing Record 2 of Set 11 | arkhangelos
# City not found. Skipping...
# Processing Record 3 of Set 11 | van buren
# Processing Record 4 of Set 11 | bonfim
# Processing Record 5 of Set 11 | fort nelson
# Processing Record 6 of Set 11 | brae
# Processing Record 7 of Set 11 | launceston
# Processing Record 8 of Set 11 | bahia blanca
# Processing Record 9 of Set 11 | bataipora
# Processing Record 10 of Set 11 | shieli
# Processing Record 11 of Set 11 | poum
# Processing Record 12 of Set 11 | palembang
# Processing Record 13 of Set 11 | uyemskiy
# Processing Record 14 of Set 11 | elizabeth city
# Processing Record 15 of Set 11 | tshela
# Processing Record 16 of Set 11 | khovu-aksy
# Processing Record 17 of Set 11 | el balyana
# City not found. Skipping...
# Processing Record 18 of Set 11 | siirt
# Processing Record 19 of Set 11 | farsund
# Processing Record 20 of Set 11 | porto velho
# Processing Record 21 of Set 11 | port blair
# Processing Record 22 of Set 11 | opuwo
# Processing Record 23 of Set 11 | valle hermoso
# Processing Record 24 of Set 11 | ahero
# Processing Record 25 of Set 11 | miyako
# Processing Record 26 of Set 11 | nyurba
# Processing Record 27 of Set 11 | adrar
# Processing Record 28 of Set 11 | huron
# Processing Record 29 of Set 11 | sassandra
# Processing Record 30 of Set 11 | nanortalik
# Processing Record 31 of Set 11 | weligama
# Processing Record 32 of Set 11 | rawatsar
# Processing Record 33 of Set 11 | suicheng
# Processing Record 34 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 35 of Set 11 | yuanping
# Processing Record 36 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 11 | syracuse
# Processing Record 38 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 39 of Set 11 | esmeralda
# Processing Record 40 of Set 11 | trzebiatow
# Processing Record 41 of Set 11 | ramganj
# Processing Record 42 of Set 11 | galgani
# City not found. Skipping...
# Processing Record 43 of Set 11 | oranjestad
# Processing Record 44 of Set 11 | gubkinskiy
# Processing Record 45 of Set 11 | las margaritas
# Processing Record 46 of Set 11 | punta alta
# Processing Record 47 of Set 11 | maumere
# Processing Record 48 of Set 11 | larsnes
# Processing Record 49 of Set 11 | hovd
# Processing Record 50 of Set 11 | ginir
# Processing Record 1 of Set 12 | nuqui
# Processing Record 2 of Set 12 | moss vale
# Processing Record 3 of Set 12 | soe
# Processing Record 4 of Set 12 | ntungamo
# Processing Record 5 of Set 12 | shugurovo
# Processing Record 6 of Set 12 | fort walton beach
# Processing Record 7 of Set 12 | akureyri
# Processing Record 8 of Set 12 | vestmannaeyjar
# Processing Record 9 of Set 12 | champa
# Processing Record 10 of Set 12 | cam pha
# City not found. Skipping...
# Processing Record 11 of Set 12 | matara
# Processing Record 12 of Set 12 | saint-joseph
# Processing Record 13 of Set 12 | vaitape
# Processing Record 14 of Set 12 | port macquarie
# Processing Record 15 of Set 12 | najran
# Processing Record 16 of Set 12 | husavik
# Processing Record 17 of Set 12 | azul
# Processing Record 18 of Set 12 | panaba
# Processing Record 19 of Set 12 | la ronge
# Processing Record 20 of Set 12 | ugoofaaru
# Processing Record 21 of Set 12 | salmas
# Processing Record 22 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 12 | tura
# Processing Record 24 of Set 12 | mackay
# Processing Record 25 of Set 12 | mitu
# Processing Record 26 of Set 12 | cabedelo
# Processing Record 27 of Set 12 | abrau-dyurso
# Processing Record 28 of Set 12 | tecoanapa
# Processing Record 29 of Set 12 | rafai
# Processing Record 30 of Set 12 | talnakh
# Processing Record 31 of Set 12 | dwarka
# Processing Record 32 of Set 12 | sri aman
# Processing Record 33 of Set 12 | kavaratti
# Processing Record 34 of Set 12 | maldonado
# Processing Record 35 of Set 12 | kletnya
# Processing Record 36 of Set 12 | changji
# Processing Record 37 of Set 12 | nueve de julio
# Processing Record 38 of Set 12 | mbini
# Processing Record 39 of Set 12 | oistins
# Processing Record 40 of Set 12 | somerset
# Processing Record 41 of Set 12 | lohmar
# Processing Record 42 of Set 12 | isla vista
# Processing Record 43 of Set 12 | zabol
# Processing Record 44 of Set 12 | boa vista
# Processing Record 45 of Set 12 | champerico
# Processing Record 46 of Set 12 | prainha
# Processing Record 47 of Set 12 | placido de castro
# Processing Record 48 of Set 12 | alta floresta
# Processing Record 49 of Set 12 | srednekolymsk
# Processing Record 50 of Set 12 | bandar maharani
# City not found. Skipping...
# Processing Record 1 of Set 13 | kalmunai
# Processing Record 2 of Set 13 | khasan
# Processing Record 3 of Set 13 | sisimiut
# Processing Record 4 of Set 13 | tazovskiy
# Processing Record 5 of Set 13 | carutapera
# Processing Record 6 of Set 13 | jiayuguan
# Processing Record 7 of Set 13 | penarroya-pueblonuevo
# Processing Record 8 of Set 13 | port-gentil
# Processing Record 9 of Set 13 | alice springs
# Processing Record 10 of Set 13 | gumdag
# Processing Record 11 of Set 13 | bowen
# Processing Record 12 of Set 13 | solsvik
# City not found. Skipping...
# Processing Record 13 of Set 13 | ciro marina
# Processing Record 14 of Set 13 | lalibela
# Processing Record 15 of Set 13 | pizarro
# Processing Record 16 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 17 of Set 13 | kumla
# Processing Record 18 of Set 13 | zelenogorskiy
# Processing Record 19 of Set 13 | vanavara
# Processing Record 20 of Set 13 | teahupoo
# Processing Record 21 of Set 13 | ulagan
# Processing Record 22 of Set 13 | san jose
# Processing Record 23 of Set 13 | port hedland
# Processing Record 24 of Set 13 | codrington
# Processing Record 25 of Set 13 | kamina
# Processing Record 26 of Set 13 | vorukh
# Processing Record 27 of Set 13 | kieta
# Processing Record 28 of Set 13 | gao
# Processing Record 29 of Set 13 | weihai
# Processing Record 30 of Set 13 | collie
# Processing Record 31 of Set 13 | verbilki
# Processing Record 32 of Set 13 | mount pleasant
# Processing Record 33 of Set 13 | kadaya
# Processing Record 34 of Set 13 | rocha
# Processing Record 35 of Set 13 | esna
# Processing Record 36 of Set 13 | emerald
# Processing Record 37 of Set 13 | berlevag
# Processing Record 38 of Set 13 | koulamoutou
# Processing Record 39 of Set 13 | tessalit
# Processing Record 40 of Set 13 | tacoronte
# Processing Record 41 of Set 13 | amahai
# Processing Record 42 of Set 13 | antofagasta
# Processing Record 43 of Set 13 | tongliao
# Processing Record 44 of Set 13 | kofele
# Processing Record 45 of Set 13 | esso
# Processing Record 46 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 47 of Set 13 | khandyga
# Processing Record 48 of Set 13 | sechelt
# Processing Record 49 of Set 13 | sabha
# Processing Record 50 of Set 13 | roebourne
# Processing Record 1 of Set 14 | rudraprayag
# Processing Record 2 of Set 14 | buchanan
# Processing Record 3 of Set 14 | basyanovskiy
# City not found. Skipping...
# Processing Record 4 of Set 14 | dondo
# Processing Record 5 of Set 14 | surt
# Processing Record 6 of Set 14 | nuuk
# Processing Record 7 of Set 14 | roald
# Processing Record 8 of Set 14 | mecca
# Processing Record 9 of Set 14 | padang
# Processing Record 10 of Set 14 | katunino
# Processing Record 11 of Set 14 | kontagora
# Processing Record 12 of Set 14 | torbat-e jam
# Processing Record 13 of Set 14 | rio rancho
# Processing Record 14 of Set 14 | waipawa
# Processing Record 15 of Set 14 | san policarpo
# Processing Record 16 of Set 14 | atambua
# Processing Record 17 of Set 14 | zheleznodorozhnyy
# Processing Record 18 of Set 14 | vao
# Processing Record 19 of Set 14 | imeni poliny osipenko
# Processing Record 20 of Set 14 | villa maria
# Processing Record 21 of Set 14 | goderich
# Processing Record 22 of Set 14 | hella
# Processing Record 23 of Set 14 | vilyuysk
# Processing Record 24 of Set 14 | cape coast
# Processing Record 25 of Set 14 | ambon
# Processing Record 26 of Set 14 | tarbagatay
# Processing Record 27 of Set 14 | santa maria
# Processing Record 28 of Set 14 | pinheiro
# Processing Record 29 of Set 14 | raleigh
# Processing Record 30 of Set 14 | kamyshla
# Processing Record 31 of Set 14 | bonavista
# Processing Record 32 of Set 14 | aklavik
# Processing Record 33 of Set 14 | aykhal
# Processing Record 34 of Set 14 | shumskiy
# Processing Record 35 of Set 14 | makueni
# Processing Record 36 of Set 14 | iqaluit
# Processing Record 37 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 38 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 39 of Set 14 | mlonggo
# Processing Record 40 of Set 14 | sao gabriel da cachoeira
# Processing Record 41 of Set 14 | jacqueville
# Processing Record 42 of Set 14 | liuhe
# Processing Record 43 of Set 14 | dourbali
# Processing Record 44 of Set 14 | bourges
# Processing Record 45 of Set 14 | taltal
# Processing Record 46 of Set 14 | santa rosa
# Processing Record 47 of Set 14 | durban
# Processing Record 48 of Set 14 | nambucca heads
# Processing Record 49 of Set 14 | mubende
# Processing Record 50 of Set 14 | iberia
# Processing Record 1 of Set 15 | kilindoni
# Processing Record 2 of Set 15 | kondinskoye
# Processing Record 3 of Set 15 | cervo
# Processing Record 4 of Set 15 | asyut
# Processing Record 5 of Set 15 | tasbuget
# City not found. Skipping...
# Processing Record 6 of Set 15 | tottori
# Processing Record 7 of Set 15 | wucheng
# Processing Record 8 of Set 15 | beloha
# Processing Record 9 of Set 15 | narimanov
# Processing Record 10 of Set 15 | maningrida
# Processing Record 11 of Set 15 | manvi
# Processing Record 12 of Set 15 | camocim
# Processing Record 13 of Set 15 | shelburne
# Processing Record 14 of Set 15 | golpayegan
# Processing Record 15 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 16 of Set 15 | lingyuan
# Processing Record 17 of Set 15 | half moon bay
# Processing Record 18 of Set 15 | ancona
# Processing Record 19 of Set 15 | jumla
# Processing Record 20 of Set 15 | macau
# Processing Record 21 of Set 15 | olsztyn
# Processing Record 22 of Set 15 | adzhamka
# Processing Record 23 of Set 15 | bahar
# Processing Record 24 of Set 15 | kimbe
# Processing Record 25 of Set 15 | nabire
# Processing Record 26 of Set 15 | biltine
# Processing Record 27 of Set 15 | nangwa
# Processing Record 28 of Set 15 | fuyu
# Processing Record 29 of Set 15 | bagotville
# Processing Record 30 of Set 15 | dharchula
# Processing Record 31 of Set 15 | huazolotitlan
# City not found. Skipping...
# Processing Record 32 of Set 15 | caravelas
# Processing Record 33 of Set 15 | sooke
# Processing Record 34 of Set 15 | broken hill
# Processing Record 35 of Set 15 | olden
# Processing Record 36 of Set 15 | bubaque
# Processing Record 37 of Set 15 | isangel
# Processing Record 38 of Set 15 | perpignan
# Processing Record 39 of Set 15 | ceres
# Processing Record 40 of Set 15 | margate
# Processing Record 41 of Set 15 | boyolangu
# Processing Record 42 of Set 15 | domoni
# Processing Record 43 of Set 15 | chapais
# Processing Record 44 of Set 15 | nexo
# Processing Record 45 of Set 15 | toora-khem
# Processing Record 46 of Set 15 | golden
# Processing Record 47 of Set 15 | jalu
# Processing Record 48 of Set 15 | puerto carreno
# Processing Record 49 of Set 15 | fare
# Processing Record 50 of Set 15 | bauru
# Processing Record 1 of Set 16 | ulladulla
# Processing Record 2 of Set 16 | milkovo
# Processing Record 3 of Set 16 | doha
# Processing Record 4 of Set 16 | ushtobe
# Processing Record 5 of Set 16 | asau
# Processing Record 6 of Set 16 | chara
# Processing Record 7 of Set 16 | sidi bu zayd
# City not found. Skipping...
# Processing Record 8 of Set 16 | wlodawa
# Processing Record 9 of Set 16 | mazagao
# Processing Record 10 of Set 16 | bargal
# City not found. Skipping...
# Processing Record 11 of Set 16 | cacador
# Processing Record 12 of Set 16 | aldama
# Processing Record 13 of Set 16 | beyneu
# Processing Record 14 of Set 16 | valparaiso
# Processing Record 15 of Set 16 | sovetskaya
# Processing Record 16 of Set 16 | baruun-urt
# Processing Record 17 of Set 16 | puerto quijarro
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
weather_df = pd.DataFrame(city_data)
weather_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Busselton      AU -33.6500  115.3333     46.00        87           0
# 1       Kapaa      US  22.0752 -159.3190     75.00       100          90
# 2     Mataura      NZ -46.1927  168.8643     61.00        76           1
# 3     Ushuaia      AR -54.8000  -68.3000     51.80        71          75
# 4     Tautira      PF -17.7333 -149.1500     87.80        66          40
# 5     Sarkand      KZ  45.4100   79.9186     41.09        52         100
# 6   Pustoshka      RU  56.3355   29.3690     34.27        97         100
# 7   Clearlake      US  38.9582 -122.6264     64.00        24           0
# 8  Casablanca      MA  33.5928   -7.6192     60.01        88          20
# 9        Hami      CN  42.8000   93.4500     47.28        35          99
#
#    Wind Speed Current Description
# 0       11.70           clear sky
# 1       11.50                mist
# 2        1.01           clear sky
# 3       31.07          light rain
# 4        8.05    scattered clouds
# 5        5.93     overcast clouds
# 6       11.83     overcast clouds
# 7        1.99           clear sky
# 8        5.75          few clouds
# 9        5.93     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the Weather_df into a CSV.
weather_df.to_csv(output_data_file, index_label="City_ID")
